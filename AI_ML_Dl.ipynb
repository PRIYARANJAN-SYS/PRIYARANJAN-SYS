# %% [markdown]
# <a href="https://colab.research.google.com/github/PRIYARANJAN-SYS/PRIYARANJAN-SYS/blob/main/AI_ML_Dl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***MACHINE LEARNING***

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns

# %% [markdown]
# importing basic libraries

# %%
sample_data=pd.read_csv('SampleSuperstore.csv')

# %%
sample_data.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
sample_data.tail(10)
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 9984  Standard Class   Consumer  United States   Long Beach    New York
# 9985  Standard Class   Consumer  United States   Long Beach    New York
# 9986  Standard Class   Consumer  United States  Los Angeles  California
# 9987  Standard Class  Corporate  United States       Athens     Georgia
# 9988  Standard Class  Corporate  United States       Athens     Georgia
# 9989    Second Class   Consumer  United States        Miami     Florida
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9984        11561   East  Office Supplies       Labels   31.500        10
# ...

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
sample_data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
sample_data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
sample_data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
sample_data.duplicated().sum()
# Out:
# 17

# %%
sample_data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
sample_data.value_counts()
# Out:
# Ship Mode       Segment      Country        City           State       Postal Code  Region   Category         Sub-Category  Sales    Quantity  Discount  Profit
# Standard Class  Consumer     United States  Salem          Oregon      97301        West     Office Supplies  Paper         10.368   2         0.2        3.6288      2
# Second Class    Corporate    United States  Chicago        Illinois    60653        Central  Office Supplies  Binders       3.564    3         0.8       -6.2370      2
# Standard Class  Consumer     United States  San Francisco  California  94122        West     Office Supplies  Paper         12.840   3         0.0        5.7780      2
#                                             Los Angeles    California  90036        West     Office Supplies  Paper         19.440   3         0.0        9.3312      2
# ...

# %%
sample_data.isnull()
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0        False         False  False     False     False   False
# ...

# %%
sample_data.isna()
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0        False         False  False     False     False   False
# ...

# %%
sample_data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # Upload file from the google drive

# %%
from google.colab import files

# %%
#upload the file
upload_file=files.upload()

df=pd.read_csv(next(iter(upload_file)))
df.head()
# Out:
#      <input type="file" id="files-f6f95f1d-7601-4d6e-b9fa-62da8103f340" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6f95f1d-7601-4d6e-b9fa-62da8103f340">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive


drive.mount('/content/drive')
#Specify the path
file_path=('/content/drive/My Drive/SampleSuperstore.csv')
df= pd.read_csv(file_path) # Use pd.read_excel to read the Excel file
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# ...

# %%
sample_data.notnull()
# Out:
#       Ship Mode  Segment  Country  City  State  Postal Code  Region  Category  \
# 0          True     True     True  True   True         True    True      True
# 1          True     True     True  True   True         True    True      True
# 2          True     True     True  True   True         True    True      True
# 3          True     True     True  True   True         True    True      True
# 4          True     True     True  True   True         True    True      True
# ...         ...      ...      ...   ...    ...          ...     ...       ...
# 9989       True     True     True  True   True         True    True      True
# 9990       True     True     True  True   True         True    True      True
# 9991       True     True     True  True   True         True    True      True
# 9992       True     True     True  True   True         True    True      True
# 9993       True     True     True  True   True         True    True      True
#
# ...

# %% [markdown]
# INDEXING AND SLICING OPERATION

# %% [markdown]
# 1. RETREVE  A SINGLE COLUMN

# %%
df['Postal Code']
# Out:
# 0       42420
# 1       42420
# 2       90036
# 3       33311
# 4       33311
#         ...
# 9989    33180
# 9990    92627
# 9991    92627
# 9992    92627
# 9993    92683
# Name: Postal Code, Length: 9994, dtype: int64

# %%
df[['Postal Code','Profit','Discount']]
# Out:
#       Postal Code    Profit  Discount
# 0           42420   41.9136      0.00
# 1           42420  219.5820      0.00
# 2           90036    6.8714      0.00
# 3           33311 -383.0310      0.45
# 4           33311    2.5164      0.20
# ...           ...       ...       ...
# 9989        33180    4.1028      0.20
# 9990        92627   15.6332      0.00
# 9991        92627   19.3932      0.20
# 9992        92627   13.3200      0.00
# 9993        92683   72.9480      0.00
#
# [9994 rows x 3 columns]

# %%
df['Postal Code'].head(29)
# Out:
# 0     42420
# 1     42420
# 2     90036
# 3     33311
# 4     33311
# 5     90032
# 6     90032
# 7     90032
# 8     90032
# 9     90032
# 10    90032
# 11    90032
# 12    28027
# 13    98103
# 14    76106
# 15    76106
# 16    53711
# 17    84084
# 18    94109
# 19    94109
# 20    94109
# 21    68025
# 22    68025
# 23    19140
# 24    84057
# 25    90049
# 26    90049
# 27    19140
# 28    19140
# Name: Postal Code, dtype: int64

# %% [markdown]
# RETRIEVE A SINGLE ROW BY INDEX

# %%
# USING ILOC (INTEGER LOCATION BASED INDEXING)

df.iloc[0]

# using loc(labeled based indexing , if DataFrame has labeled name)
df.loc[0]
# Out:
# Ship Mode        Second Class
# Segment              Consumer
# Country         United States
# City                Henderson
# State                Kentucky
# Postal Code             42420
# Region                  South
# Category            Furniture
# Sub-Category        Bookcases
# Sales                  261.96
# Quantity                    2
# Discount                  0.0
# Profit                41.9136
# Name: 0, dtype: object

# %% [markdown]
# RETRIVE MULTIPLE ROWS BY INDEX

# %%
df.iloc[0:6]
# df.loc[0:2]
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
# ...

# %% [markdown]
# Retrieve specific rows and columns

# %%
df.iloc[0:5,[0,1,2,3]]
# Out:
#         Ship Mode    Segment        Country             City
# 0    Second Class   Consumer  United States        Henderson
# 1    Second Class   Consumer  United States        Henderson
# 2    Second Class  Corporate  United States      Los Angeles
# 3  Standard Class   Consumer  United States  Fort Lauderdale
# 4  Standard Class   Consumer  United States  Fort Lauderdale

# %%
df.loc[0:5,['Postal Code','Profit','Discount']]
# Out:
#    Postal Code    Profit  Discount
# 0        42420   41.9136      0.00
# 1        42420  219.5820      0.00
# 2        90036    6.8714      0.00
# 3        33311 -383.0310      0.45
# 4        33311    2.5164      0.20
# 5        90032   14.1694      0.00

# %% [markdown]
# Retrieve rows based on a condition

# %%
df[df['Profit']>=300]
# Out:
#            Ship Mode      Segment        Country           City       State  \
# 149   Standard Class    Corporate  United States       Franklin   Wisconsin
# 244     Second Class  Home Office  United States      Lakeville   Minnesota
# 247     Second Class  Home Office  United States      Lakeville   Minnesota
# 251   Standard Class     Consumer  United States      San Diego  California
# 281     Second Class     Consumer  United States        Houston       Texas
# ...              ...          ...            ...            ...         ...
# 9925     First Class    Corporate  United States  New York City    New York
# 9929        Same Day     Consumer  United States  San Francisco  California
# 9947    Second Class    Corporate  United States   Indianapolis     Indiana
# 9948    Second Class    Corporate  United States   Indianapolis     Indiana
# 9968  Standard Class     Consumer  United States     Plainfield  New Jersey
#
# ...

# %%
df[(df['Segment']=='Corporate')& (df['City']=="New York")]
# Out:
# Empty DataFrame
# Columns: [Ship Mode, Segment, Country, City, State, Postal Code, Region, Category, Sub-Category, Sales, Quantity, Discount, Profit]
# Index: []

# %%
df.iloc[0:5,0:3]
# Out:
#         Ship Mode    Segment        Country
# 0    Second Class   Consumer  United States
# 1    Second Class   Consumer  United States
# 2    Second Class  Corporate  United States
# 3  Standard Class   Consumer  United States
# 4  Standard Class   Consumer  United States

# %%
df.loc[0:4,'Ship Mode':'Country']
# Out:
#         Ship Mode    Segment        Country
# 0    Second Class   Consumer  United States
# 1    Second Class   Consumer  United States
# 2    Second Class  Corporate  United States
# 3  Standard Class   Consumer  United States
# 4  Standard Class   Consumer  United States

# %%
sample_data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#np.cov(sample_data) # Covarience it is the part of statistics

# %%
sample_data1=sample_data.copy()
sample_data1
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
sample_data1=sample_data1.drop(columns='Postal Code',axis=1)

# %%
sample_data1.head(3)
# Out:
#       Ship Mode    Segment        Country         City       State Region  \
# 0  Second Class   Consumer  United States    Henderson    Kentucky  South
# 1  Second Class   Consumer  United States    Henderson    Kentucky  South
# 2  Second Class  Corporate  United States  Los Angeles  California   West
#
#           Category Sub-Category   Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.96         2       0.0   41.9136
# 1        Furniture       Chairs  731.94         3       0.0  219.5820
# 2  Office Supplies       Labels   14.62         2       0.0    6.8714

# %% [markdown]
# visualisation part

# %%
plt.figure(figsize=(20,5))
plt.bar('Sub-Category','Category',data=sample_data1)
plt.show()

# %% [markdown]
# **BAR CHART**

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=sample_data1['State'])
plt.xticks(rotation=75)
plt.show()

# %%
print(sample_data1['Sub-Category'].value_counts())
plt.figure(figsize=(20,20))
sns.countplot(x=sample_data1['Sub-Category'],palette='coolwarm')
plt.xticks(rotation=75)



plt.show()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64
# <ipython-input-47-55289a7c8201>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=sample_data1['Sub-Category'],palette='coolwarm')

# %%
sns.countplot(x=sample_data1['Region'],palette='rocket_r')

# %% [markdown]
# CASE STUDY **ANAYSIS**

# %%
number_cols=sample_data1.select_dtypes(include=['number'])

number_cols.mean()
# Out:
# Postal Code    55190.379428
# Sales            229.858001
# Quantity           3.789574
# Discount           0.156203
# Profit            28.656896
# dtype: float64

# %%
number_cols.median()
# Out:
# Postal Code    56430.5000
# Sales             54.4900
# Quantity           3.0000
# Discount           0.2000
# Profit             8.6665
# dtype: float64

# %%
number_cols.mode()
# Out:
#    Postal Code  Sales  Quantity  Discount  Profit
# 0        10035  12.96         3       0.0     0.0

# %%
number_cols.cov()
# Out:
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228
# Quantity     9.104159e+02     278.459923    4.951113    0.003961
# Discount     3.868704e+02      -3.627228    0.003961    0.042622
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173
#
#                     Profit
# Postal Code -225045.849445
# Sales         69944.096586
# Quantity         34.534769
# Discount        -10.615173
# Profit        54877.798055

# %%
number_cols.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
#box plot
plt.figure(figsize=(20,10))
sns.boxplot(x=sample_data1['Sub-Category'],y=sample_data1['Profit'])

plt.show()

# %%
sns.boxplot(sample_data1['Discount'])
# Out:
# <Axes: ylabel='Discount'>

# %%
#HISTOGRAM
plt.figure(figsize=(5,5))
sns.histplot(data=sample_data1, x='Profit',bins=15,color='pink',edgecolor='red')
plt.show
